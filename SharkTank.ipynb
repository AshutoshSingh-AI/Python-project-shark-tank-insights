# %% [markdown]
# # **SHARK TANK INDIA**

# %% [markdown]
# # **About**
#
# Shark Tank India is an indian Hindi-language buisness reality television series entertainment Television.The show is the indian franchise of the American show Shark Tank.It shows enterpreneurs making buisness presentations to a panel of investors or sharks ,who decide whether to invest in their company.This data is about the first season of Shark Tank premiered on 20 December 2021 ,and Concluded on 4 February 2022.

# %% [markdown]
# # **Importing all the necessary modules.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Reading the Dataset.**

# %%
df=pd.read_csv('/content/Shark Tank India Dataset.xls')
df



#ask_valuation=(ask_amount/ask_equity)*100 : (50/5)*100=1000
# Out:
#      episode_number  pitch_number           brand_name  \
# 0                 1             1  BluePine Industries
# 1                 1             2        Booz scooters
# 2                 1             3  Heart up my Sleeves
# 3                 2             4           Tagz Foods
# 4                 2             5       Head and Heart
# ..              ...           ...                  ...
# 112              34           113        Green Protein
# 113              34           114              On2Cook
# 114              35           115        Jain Shikanji
# 115              35           116                Woloo
# 116              35           117         Elcare India
#
#                                               idea  deal  pitcher_ask_amount  \
# 0                                     Frozen Momos     1                50.0
# 1    Renting e-bike for mobility in private spaces     1                40.0
# ...

# %%
df.head()
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# 4                       Brain Development Course     0                50.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0        16.00  ...             1
# ...

# %%
df.shape
# Out:
# (117, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %% [markdown]
# # **No of sucessfull deals & unsuccessfull.**

# %%
df['deal'].value_counts()
# Out:
# deal
# 1    65
# 0    52
# Name: count, dtype: int64

# %%
df['deal'].value_counts(normalize=True)
# Out:
# deal
# 1    0.555556
# 0    0.444444
# Name: proportion, dtype: float64

# %%
df['deal'].value_counts().plot(autopct='%1.2f%%',kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # **Most dealing episode.**

# %%
df.groupby('episode_number')['deal'].sum().sort_values(ascending=False).reset_index()
# Out:
#     episode_number  deal
# 0                1     3
# 1               15     3
# 2               21     3
# 3               33     3
# 4                8     3
# 5               10     3
# 6               17     3
# 7               16     3
# 8               13     3
# 9               25     2
# 10              24     2
# 11              28     2
# 12              20     2
# 13              26     2
# 14              27     2
# 15              12     2
# 16              11     2
# 17               9     2
# 18               6     2
# 19               4     2
# 20               3     2
# 21              31     1
# 22              30     1
# 23              29     1
# 24              34     1
# 25              32     1
# 26              18     1
# 27              23     1
# 28              22     1
# 29              19     1
# 30               2     1
# 31              14     1
# 32               7     1
# 33               5     1
# 34              35     1

# %%
sns.catplot(x='deal',y='episode_number',kind='swarm',hue='deal',data=df);

# %% [markdown]
# # **Most expensive dealing episode.**

# %%
A=df.groupby('episode_number')['deal_amount'].sum().sort_values(ascending=False).reset_index()

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.bar(A['episode_number'],A['deal_amount'])
plt.xticks(A['episode_number'],rotation=90,fontsize=8)
plt.show()

# %% [markdown]
# # **All sharks In.**

# %%
df[df['total_sharks_invested']==5]
# Out:
#     episode_number  pitch_number             brand_name                 idea  \
# 15               6            16            Skippi Pops             Ice-Pops
# 49              17            50  Find Your Kicks India       Sneaker Resale
# 63              20            64               IN A CAN        Can Cocktails
# 79              25            80    Sunfox Technologies  Portable ECG Device
#
#     deal  pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  \
# 15     1                45.0         5.0          900.0        100.0
# 49     1                50.0        10.0          500.0         50.0
# 63     1                50.0         2.0         2500.0        100.0
# 79     1               100.0         2.0         5000.0        100.0
#
#     deal_equity  ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  \
# 15         15.0  ...             1            1          1            1
# 49         25.0  ...             1            1          1            1
# ...

# %% [markdown]
# # **No. of sharks invested with respect to Buisness.**

# %%
df['total_sharks_invested'].value_counts()
# Out:
# total_sharks_invested
# 0    52
# 1    22
# 2    20
# 3    14
# 4     5
# 5     4
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.title('Maximum Sharks Invested')
plt.bar(df['episode_number'],df['total_sharks_invested'])
plt.xticks(df['episode_number'].unique(),rotation=90);

# %% [markdown]
# # **No Bargain deal.**

# %%
df[(df['pitcher_ask_amount']==df['deal_amount']) & (df['ask_equity']==df['deal_equity'])]
# Out:
#     episode_number  pitch_number    brand_name                 idea  deal  \
# 21               8            22  Beyond Snack  Kerala Banana Chips     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 21                50.0         2.5         2000.0         50.0          2.5
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 21  ...             1            0          1            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 21            0            0                      2              25.0
#
#     equity_per_shark
# 21              1.25
#
# [1 rows x 28 columns]

# %% [markdown]
# # **Created a function that show the equity and amount per shark.**

# %%
def sharks(data):
  list=['anupam_deal',	'aman_deal'	,'namita_deal','vineeta_deal'	,'peyush_deal'	,'ghazal_deal','ashneer_deal']
  for i in list:
    deal=data[['amount_per_shark','equity_per_shark']][data[i]==1]
    print ('\n',len(deal),'deals with',i[:-5])
    print(deal)

# %% [markdown]
# # **Ashneer Deal**

# %%
ash_grover = df[df['ashneer_deal']==1]
ash_grover
# Out:
#      episode_number  pitch_number             brand_name  \
# 0                 1             1    BluePine Industries
# 1                 1             2          Booz scooters
# 3                 2             4             Tagz Foods
# 15                6            16            Skippi Pops
# 18                7            19     Raising Superstars
# 21                8            22           Beyond Snack
# 23                8            24          Motion Breeze
# 29               10            30              EventBeep
# 38               13            39        The Yarn Bazaar
# 45               16            46           Bamboo India
# 49               17            50  Find Your Kicks India
# 50               17            51          Aas Vidyalaya
# 55               18            56                   Otua
# 58               19            59                WeSTOCK
# 63               20            64               IN A CAN
# ...

# %%
sharks(ash_grover)
# Out:
#  8 deals with anupam
#      amount_per_shark  equity_per_shark
# 15               20.0          3.000000
# 38               25.0          2.500000
# 45               25.0          1.750000
# 49               10.0          5.000000
# 63               20.0          2.000000
# 67               20.0          1.333333
# 108              20.0          3.333333
# 114              10.0          7.500000
#
#  11 deals with aman
#      amount_per_shark  equity_per_shark
# 0           25.000000          5.333333
# 15          20.000000          3.000000
# 18          50.000000          2.000000
# 21          25.000000          1.250000
# 29          10.000000          1.000000
# 38          25.000000          2.500000
# 49          10.000000          5.000000
# 58          15.000000          2.500000
# 63          20.000000          2.000000
# 64          33.333333          5.000000
# 114         10.000000          7.500000
#
#  6 deals with namita
#      amount_per_shark  equity_per_shark
# ...

# %%
amt=ash_grover['amount_per_shark'].sum()
amt
# Out:
# 494.33333333

# %%
eqt=ash_grover['equity_per_shark'].sum()
eqt
# Out:
# 93.249999999

# %%
ash_grover[ash_grover['equity_per_shark']==ash_grover['equity_per_shark'].max()]
# Out:
#    episode_number  pitch_number     brand_name  \
# 1               1             2  Booz scooters
#
#                                             idea  deal  pitcher_ask_amount  \
# 1  Renting e-bike for mobility in private spaces     1                40.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 1        15.0         266.67         40.0         50.0  ...             1
#
#    anupam_deal  aman_deal  namita_deal  vineeta_deal  peyush_deal  \
# 1            0          0            0             1            0
#
#    ghazal_deal  total_sharks_invested  amount_per_shark  equity_per_shark
# 1            0                      2              20.0              25.0
#
# [1 rows x 28 columns]

# %% [markdown]
# # **Anupam Deal**

# %%
anu_deal = df[df['anupam_deal']==1]
anu_deal
# Out:
#      episode_number  pitch_number                      brand_name  \
# 2                 1             3             Heart up my Sleeves
# 9                 4            10                           Cosiq
# 12                5            13                     Revamp Moto
# 15                6            16                     Skippi Pops
# 22                8            23  Vivalyf Innovations- Easy Life
# 28               10            29                        Meatyour
# 31               11            32        ARRCOAT Surface Textures
# 35               12            36                            LOKA
# 36               13            37                           Annie
# 37               13            38                       Caragreen
# 38               13            39                 The Yarn Bazaar
# 44               15            45                         Cocofit
# 45               16            46                    Bamboo India
# ...

# %%
sharks(anu_deal)
# Out:
#  24 deals with anupam
#      amount_per_shark  equity_per_shark
# 2           12.500000         15.000000
# 9           25.000000         12.500000
# 12          50.000000          0.750000
# 15          20.000000          3.000000
# 22          28.000000         16.650000
# 28          10.000000          6.666667
# 31          50.000000         15.000000
# 35          13.333333          8.000000
# 36          35.000000          1.000000
# 37          25.000000         10.000000
# 38          25.000000          2.500000
# 44           0.000017          1.666667
# 45          25.000000          1.750000
# 48          22.500000          6.000000
# 49          10.000000          5.000000
# 63          20.000000          2.000000
# 66          17.500000         12.000000
# 67          20.000000          1.333333
# 75          25.000000         17.500000
# 78          50.000000         15.000000
# 79          20.000000          1.200000
# 85           0.000253          1.000000
# ...

# %%
eqt = df.groupby('anupam_deal')['equity_per_shark'].sum()[1]
amt = df.groupby('anupam_deal')['amount_per_shark'].sum()[1]
print("Total equity buy on shark tank by Anupam",eqt,'%')
print("Total amount invested on shark tank by Anupam",amt,"lakhs")
# Out:
# Total equity buy on shark tank by Anupam 166.35 %
# Total amount invested on shark tank by Anupam 533.83360253 lakhs

# %%
anu_deal['amount_per_shark'].sum()
# Out:
# 533.83360253

# %%
anu_deal['equity_per_shark'].sum()
# Out:
# 166.35

# %%
anu_deal[anu_deal['equity_per_shark']==anu_deal['equity_per_shark'].max()]
# Out:
#     episode_number  pitch_number    brand_name   idea  deal  \
# 75              24            76  The Sass Bar  Gifts     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 75                40.0         8.0          500.0         50.0         35.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 75  ...             0            1          0            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 75            0            1                      2              25.0
#
#     equity_per_shark
# 75              17.5
#
# [1 rows x 28 columns]

# %%
anu_deal[anu_deal['equity_per_shark']==anu_deal['equity_per_shark'].max()]
# Out:
#     episode_number  pitch_number    brand_name   idea  deal  \
# 75              24            76  The Sass Bar  Gifts     1
#
#     pitcher_ask_amount  ask_equity  ask_valuation  deal_amount  deal_equity  \
# 75                40.0         8.0          500.0         50.0         35.0
#
#     ...  ashneer_deal  anupam_deal  aman_deal  namita_deal  vineeta_deal  \
# 75  ...             0            1          0            0             0
#
#     peyush_deal  ghazal_deal  total_sharks_invested  amount_per_shark  \
# 75            0            1                      2              25.0
#
#     equity_per_shark
# 75              17.5
#
# [1 rows x 28 columns]

# %% [markdown]
# # **Aman Deal**

# %%
aman_deal = df[df['aman_deal']==1]
aman_deal
# Out:
#      episode_number  pitch_number             brand_name  \
# 0                 1             1    BluePine Industries
# 7                 3             8              Peeschute
# 11                4            12                 Bummer
# 12                5            13            Revamp Moto
# 15                6            16            Skippi Pops
# 18                7            19     Raising Superstars
# 21                8            22           Beyond Snack
# 24                9            25                  Altor
# 25                9            26                  Ariro
# 27               10            28                Nuutjob
# 28               10            29               Meatyour
# 29               10            30              EventBeep
# 32               11            33                  Farda
# 35               12            36                   LOKA
# 38               13            39        The Yarn Bazaar
# ...

# %%
sharks(aman_deal)
# Out:
#  10 deals with anupam
#      amount_per_shark  equity_per_shark
# 12          50.000000          0.750000
# 15          20.000000          3.000000
# 28          10.000000          6.666667
# 35          13.333333          8.000000
# 38          25.000000          2.500000
# 44           0.000017          1.666667
# 48          22.500000          6.000000
# 49          10.000000          5.000000
# 63          20.000000          2.000000
# 114         10.000000          7.500000
#
#  28 deals with aman
#      amount_per_shark  equity_per_shark
# 0           25.000000          5.333333
# 7           75.000000          6.000000
# 11          37.500000          3.750000
# 12          50.000000          0.750000
# 15          20.000000          3.000000
# 18          50.000000          2.000000
# 21          25.000000          1.250000
# 24          25.000000          3.500000
# 25          25.000000          5.000000
# 27           8.333333          6.666667
# ...

# %% [markdown]
# # **Namita Deal**

# %%
nami_deal = df[df['namita_deal']==1]
nami_deal
# Out:
#      episode_number  pitch_number             brand_name  \
# 11                4            12                 Bummer
# 15                6            16            Skippi Pops
# 16                6            17           Menstrupedia
# 24                9            25                  Altor
# 27               10            28                Nuutjob
# 32               11            33                  Farda
# 33               12            34         Auli Lifestyle
# 36               13            37                  Annie
# 39               14            40      The Renal Project
# 44               15            45                Cocofit
# 47               16            48           Beyond Water
# 49               17            50  Find Your Kicks India
# 50               17            51          Aas Vidyalaya
# 58               19            59                WeSTOCK
# 63               20            64               IN A CAN
# ...

# %%
sharks(nami_deal)
# Out:
#  7 deals with anupam
#     amount_per_shark  equity_per_shark
# 15         20.000000          3.000000
# 36         35.000000          1.000000
# 44          0.000017          1.666667
# 49         10.000000          5.000000
# 63         20.000000          2.000000
# 79         20.000000          1.200000
# 85          0.000253          1.000000
#
#  11 deals with aman
#     amount_per_shark  equity_per_shark
# 11         37.500000          3.750000
# 15         20.000000          3.000000
# 24         25.000000          3.500000
# 27          8.333333          6.666667
# 32         15.000000         10.000000
# 39         50.000000          3.000000
# 44          0.000017          1.666667
# 47         37.500000          7.500000
# 49         10.000000          5.000000
# 58         15.000000          2.500000
# 63         20.000000          2.000000
#
#  22 deals with namita
#      amount_per_shark  equity_per_shark
# 11          37.500000          3.750000
# ...

# %% [markdown]
# # **Vineeta Deal**

# %%
vine_deal = df[df['vineeta_deal']==1]
vine_deal
# Out:
#      episode_number  pitch_number                brand_name  \
# 0                 1             1       BluePine Industries
# 1                 1             2             Booz scooters
# 2                 1             3       Heart up my Sleeves
# 8                 3             9                      NOCD
# 9                 4            10                     Cosiq
# 15                6            16               Skippi Pops
# 64               21            65                Get a Whey
# 66               21            67           The Quirky Nari
# 79               25            80       Sunfox Technologies
# 88               28            89                  Humpy A2
# 90               28            91  Gold Safe Solutions Ind.
# 91               29            92               Wakao Foods
# 95               30            96              Kabaddi Adda
# 110              34           111        Nomad Food Project
# 114              35           115             Jain Shikanji
#
# ...

# %%
sharks(vine_deal)
# Out:
#  6 deals with anupam
#      amount_per_shark  equity_per_shark
# 2                12.5              15.0
# 9                25.0              12.5
# 15               20.0               3.0
# 66               17.5              12.0
# 79               20.0               1.2
# 114              10.0               7.5
#
#  4 deals with aman
#      amount_per_shark  equity_per_shark
# 0           25.000000          5.333333
# 15          20.000000          3.000000
# 64          33.333333          5.000000
# 114         10.000000          7.500000
#
#  5 deals with namita
#      amount_per_shark  equity_per_shark
# 15               20.0               3.0
# 79               20.0               1.2
# 91               25.0               7.0
# 95               40.0               3.0
# 110              10.0               5.0
#
#  15 deals with vineeta
#      amount_per_shark  equity_per_shark
# 0           25.000000          5.333333
# 1           20.000000         25.000000
# ...

# %% [markdown]
# # **Peyush Deal**

# %%
piyu_deal = df[df['peyush_deal']==1]
piyu_deal
# Out:
#      episode_number  pitch_number                      brand_name  \
# 22                8            23  Vivalyf Innovations- Easy Life
# 25                9            26                           Ariro
# 27               10            28                         Nuutjob
# 28               10            29                        Meatyour
# 29               10            30                       EventBeep
# 35               12            36                            LOKA
# 36               13            37                           Annie
# 37               13            38                       Caragreen
# 38               13            39                 The Yarn Bazaar
# 43               15            44                             PNT
# 49               17            50           Find Your Kicks India
# 50               17            51                   Aas Vidyalaya
# 52               17            53                      RoadBounce
# ...

# %%
sharks(piyu_deal)
# Out:
#  12 deals with anupam
#      amount_per_shark  equity_per_shark
# 22          28.000000         16.650000
# 28          10.000000          6.666667
# 35          13.333333          8.000000
# 36          35.000000          1.000000
# 37          25.000000         10.000000
# 38          25.000000          2.500000
# 49          10.000000          5.000000
# 63          20.000000          2.000000
# 67          20.000000          1.333333
# 79          20.000000          1.200000
# 85           0.000253          1.000000
# 108         20.000000          3.333333
#
#  9 deals with aman
#     amount_per_shark  equity_per_shark
# 25         25.000000          5.000000
# 27          8.333333          6.666667
# 28         10.000000          6.666667
# 29         10.000000          1.000000
# 35         13.333333          8.000000
# 38         25.000000          2.500000
# 49         10.000000          5.000000
# 58         15.000000          2.500000
# ...

# %% [markdown]
# # **Ghazal Deal**

# %%
ghaz_deal = df[df['ghazal_deal']==1]
ghaz_deal
# Out:
#      episode_number  pitch_number                brand_name  \
# 75               24            76              The Sass Bar
# 79               25            80       Sunfox Technologies
# 85               27            86        Watt Technovations
# 88               28            89                  Humpy A2
# 90               28            91  Gold Safe Solutions Ind.
# 91               29            92               Wakao Foods
# 110              34           111        Nomad Food Project
#
#                       idea  deal  pitcher_ask_amount  ask_equity  \
# 75                   Gifts     1            40.00000         8.0
# 79     Portable ECG Device     1           100.00000         2.0
# 85     Ventilated PPE Kits     1             0.00101        10.0
# 88   Organic Milk Products     1            75.00000         4.0
# 90   Anti-Suicidal Fan Rod     1            50.00000         5.0
# 91      Jackfruit Products     1            75.00000         5.0
# ...

# %%
sharks(ghaz_deal)
# Out:
#  3 deals with anupam
#     amount_per_shark  equity_per_shark
# 75         25.000000              17.5
# 79         20.000000               1.2
# 85          0.000253               1.0
#
#  0 deals with aman
# Empty DataFrame
# Columns: [amount_per_shark, equity_per_shark]
# Index: []
#
#  4 deals with namita
#      amount_per_shark  equity_per_shark
# 79          20.000000               1.2
# 85           0.000253               1.0
# 91          25.000000               7.0
# 110         10.000000               5.0
#
#  5 deals with vineeta
#      amount_per_shark  equity_per_shark
# 79          20.000000               1.2
# 88          33.333333               5.0
# 90          16.666667              10.0
# 91          25.000000               7.0
# 110         10.000000               5.0
#
#  4 deals with peyush
#     amount_per_shark  equity_per_shark
# 79         20.000000               1.2
# 85          0.000253               1.0
# 88         33.333333               5.0
# ...

# %% [markdown]
# # **Number of Sharks Deal**

# %%
X=df[df['total_sharks_invested']>=0]

X['total_sharks_invested'].value_counts()
# Out:
# total_sharks_invested
# 0    52
# 1    22
# 2    20
# 3    14
# 4     5
# 5     4
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,7))
plt.hist(X.total_sharks_invested)
plt.yticks(X['total_sharks_invested'].value_counts().values)
plt.title('visualization of number of Sharks teamedup')
plt.xlabel('Number of Sharks')
plt.ylabel('Number of Investments');

# %%
plt.figure(dpi=200)
plt.scatter(X['brand_name'],X['total_sharks_invested'],s=9);

plt.xticks(rotation=90,fontsize=6)

plt.show()

# %% [markdown]
# # **Total amount Invested by sharks in different companies(in lakhs).**

# %%
t=ash_grover['amount_per_shark'].sum()
t2=aman_deal['amount_per_shark'].sum()
t3=nami_deal['amount_per_shark'].sum()
t4=vine_deal['amount_per_shark'].sum()
t5=piyu_deal['amount_per_shark'].sum()
t6=ghaz_deal['amount_per_shark'].sum()
t7=anu_deal['amount_per_shark'].sum()
print(t)
print(t2)
print(t3)
print(t4)
print(t5)
print(t6)
print(t7)
# Out:
# 494.33333333
# 887.500016693
# 648.333602533
# 328.3333333300001
# 719.6669191630001
# 130.0002525
# 533.83360253

# %% [markdown]
# # Which shark invested in more company.

# %%
D=[]
list = ['anupam_deal','aman_deal','namita_deal','vineeta_deal','peyush_deal','ghazal_deal','ashneer_deal']
for i in list:
    deal = df[i].sum()
    D.append(deal)
    print(i,"deals with",deal,"companies" )
# Out:
# anupam_deal deals with 24 companies
# aman_deal deals with 28 companies
# namita_deal deals with 22 companies
# vineeta_deal deals with 15 companies
# peyush_deal deals with 27 companies
# ghazal_deal deals with 7 companies
# ashneer_deal deals with 21 companies

# %%
plt.bar(list,D)
plt.xticks(rotation=90);

# %% [markdown]
# # **Which shark present at the time of company.**

# %%
p=[]
list = ['anupam_present','aman_present','namita_present','vineeta_present','peyush_present','ghazal_present','ashneer_present']
for i in list:
    pres = df[i].sum()
    p.append(pres)
    print(i,"present in front of",pres,"companies" )
# Out:
# anupam_present present in front of 117 companies
# aman_present present in front of 98 companies
# namita_present present in front of 106 companies
# vineeta_present present in front of 66 companies
# peyush_present present in front of 88 companies
# ghazal_present present in front of 26 companies
# ashneer_present present in front of 98 companies

# %%
plt.bar(list,p)
plt.xticks(rotation=90);
